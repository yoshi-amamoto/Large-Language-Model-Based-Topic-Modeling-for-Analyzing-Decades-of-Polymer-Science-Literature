# %% [markdown]
# # Calculation of coherence for Figure 2d

# %%
import pandas as pd
import json

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora.dictionary import Dictionary
# Out:
# [nltk_data] Downloading package punkt to /Users/yoshi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
path = '***'

# %% [markdown]
# # 1. Data loading

# %%
df=pd.read_csv(path+'data/Polymer2.csv')
df
# Out:
#         Unnamed: 0    Reference Type  Year  \
# 0                0   Journal Article  1990
# 1                0   Journal Article  1990
# 2                0   Journal Article  1990
# 3                0   Journal Article  1990
# 4                0   Journal Article  1990
# ...            ...               ...   ...
# 275733           0   Journal Article  2024
# 275734           0   Journal Article  2024
# 275735           0   Journal Article  2024
# 275736           0   Journal Article  2024
# 275737           0   Journal Article  2024
#
#                                                     Title  \
# 0       Arylidene Polymers .5. Synthesis, Characteriza...
# 1       Apatite Coating on Ceramics, Metals and Polyme...
# 2                            New Aspects of Polymer Drugs
# 3                    Polymer Gels in Uniaxial Deformation
# 4       Glass-Transition in Polymers - Freezing of Rot...
# ...                                                   ...
# 275733  Corona: An effective polarization strategy of ...
# 275734  Electrospray deposited plant-based polymer nan...
# 275735  Shape- and polymer-considered simulation to un...
# 275736  High-efficient Ag(I) ion binding, Ag(0) nanopa...
# 275737  An interpenetrating polymer networks based on ...
#
#                                                    Author  \
# 0                                          Abdalla, M. A.
# 1                    Abe, Y., Kokubo, T. and Yamamuro, T.
# 2                             Akashi, M. and Takemoto, K.
# 3                             Alexander, S. and Rabin, Y.
# 4        Allegra, G., Bignotti, F., Gargani, L. and Co...
# ...                                                   ...
# 275733   Yi, J., Ye, Z. W., Zhang, S. X., Song, Y. H.,...
# 275734                        Yontar, A. K. and Çevik, S.
# 275735   Zeng, Y. C., Wang, H., Liang, D. F., Yuan, W....
# 275736   Zhang, J., Pu, N., Li, M. L., Sang, W. H., He...
# 275737            Zhang, J. W., Rui, C. C. and Jia, C. J.
#
#                                                   Journal  \
# 0             Journal of Macromolecular Science-Chemistry
# 1       Journal of Materials Science-Materials in Medi...
# 2                             Advances in Polymer Science
# 3                     Journal of Physics-Condensed Matter
# 4                                          Macromolecules
# ...                                                   ...
# 275733                                     Applied Energy
# 275734                       Progress in Organic Coatings
# 275735                     Journal of Hazardous Materials
# 275736             Separation and Purification Technology
# 275737                                     Food Chemistry
#
#                                                  Abstract  Times Cited  \
# 0       A new [(2-oxo-1,3-cyclopentanediylidene)bis(me...          NaN
# 1       A novel method of apatite coating is presented...         14.0
# 2       This article reviews results on the studies of...          9.0
# 3       The recent analysis of osmotic pressure in a s...          1.0
# 4       A nonlattice model based on space-filling crit...          NaN
# ...                                                   ...          ...
# 275733  Piezoelectric nanogenerators (PENGs) are mushr...          NaN
# 275734  The present study was designed to apply the El...          NaN
# 275735  Environmental microplastics (MPs) constitute v...          NaN
# 275736  Interest in functional silver has rapidly grow...          NaN
# 275737  The separation of valuable sugar components fr...          NaN
#
#              ISSN
# 0       0022-233x
# 1       0957-4530
# 2       0065-3195
# 3       0953-8984
# 4       0024-9297
# ...           ...
# 275733  0306-2619
# 275734  0300-9440
# 275735  0304-3894
# 275736  1383-5866
# 275737  0308-8146
#
# [275738 rows x 9 columns]

# %%
df['Title']
# Out:
# 0         Arylidene Polymers .5. Synthesis, Characteriza...
# 1         Apatite Coating on Ceramics, Metals and Polyme...
# 2                              New Aspects of Polymer Drugs
# 3                      Polymer Gels in Uniaxial Deformation
# 4         Glass-Transition in Polymers - Freezing of Rot...
#                                 ...
# 275733    Corona: An effective polarization strategy of ...
# 275734    Electrospray deposited plant-based polymer nan...
# 275735    Shape- and polymer-considered simulation to un...
# 275736    High-efficient Ag(I) ion binding, Ag(0) nanopa...
# 275737    An interpenetrating polymer networks based on ...
# Name: Title, Length: 275738, dtype: object

# %% [markdown]
# # 2. Calculation of coherence for titles

# %%
tokenized_docs = [word_tokenize(doc.lower()) for doc in df['Title']]
dictionary = Dictionary(tokenized_docs)

model_name = ["BERT", "SciBERT", "MatSciBERT"]
coherence_list = []

for name in model_name:
    with open(path + "models/title/topic_words_" + name + "_title", "r", encoding="utf-8") as f:
        topic_words = json.load(f)

    filtered_topic_words = [
        [word for word in topic if word in dictionary.token2id]
        for topic in topic_words
        if isinstance(topic, list)
    ]

    filtered_topic_words = [topic for topic in filtered_topic_words if topic]

    coherence_model = CoherenceModel(
        topics=filtered_topic_words,
        texts=tokenized_docs,
        dictionary=dictionary,
        coherence='c_v'
    )

    score = coherence_model.get_coherence()
    print(f"Coherence score for {name}: {score}")
    coherence_list.append((name, score))

pd.DataFrame(coherence_list, columns=["Model", "Coherence"]).to_csv(path + "models/title/coherence_title.csv", index=False)
# Out:
# Coherence score for BERT: 0.4402981375759279
# Coherence score for SciBERT: 0.4606004303810137
# Coherence score for MatSciBERT: 0.47871349070873087

# %% [markdown]
# # 3. Calculation of coherence for abstracts

# %%
tokenized_docs = [word_tokenize(doc.lower()) for doc in df['Abstract']]
dictionary = Dictionary(tokenized_docs)

model_name = ["BERT", "SciBERT", "MatSciBERT"]
coherence_list = []

for name in model_name:
    with open(path + "models/abstract/topic_words_" + name + "_abstract", "r", encoding="utf-8") as f:
        topic_words = json.load(f)

    filtered_topic_words = [
        [word for word in topic if word in dictionary.token2id]
        for topic in topic_words
        if isinstance(topic, list)
    ]

    filtered_topic_words = [topic for topic in filtered_topic_words if topic]

    coherence_model = CoherenceModel(
        topics=filtered_topic_words,
        texts=tokenized_docs,
        dictionary=dictionary,
        coherence='c_v'
    )

    score = coherence_model.get_coherence()
    print(f"Coherence score for {name}: {score}")
    coherence_list.append((name, score))

pd.DataFrame(coherence_list, columns=["Model", "Coherence"]).to_csv(path + "models/abstract/coherence_abstract.csv", index=False)
# Out:
# Coherence score for BERT: 0.4560397628500703
# Coherence score for SciBERT: 0.5333310594604677
# Coherence score for MatSciBERT: 0.54881815539565
